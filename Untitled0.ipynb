# %% [markdown]
# <a href="https://colab.research.google.com/github/JAMUNAASHREE18/jamunaa-codebooster1-2026/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
df=pd.read_csv('student_performance.csv')

# %%
print(df)
# Out:
#     student_id            name  age  gender        department  semester  \
# 0         1001    Aarav Sharma   19    Male  Computer Science         2
# 1         1002     Priya Patel   20  Female  Computer Science         2
# 2         1003     Rohit Verma   19    Male       Electronics         2
# 3         1004     Sneha Reddy   20  Female        Mechanical         2
# 4         1005      Arjun Nair   19    Male  Computer Science         2
# 5         1006     Meera Joshi   20  Female       Electronics         2
# 6         1007     Kiran Kumar   21    Male             Civil         2
# 7         1008     Divya Singh   19  Female  Computer Science         2
# 8         1009    Rahul Mishra   20    Male        Mechanical         2
# 9         1010      Ananya Das   19  Female  Computer Science         2
# 10        1011     Vikram Iyer   20    Male       Electronics         2
# 11        1012     Pooja Gupta   19  Female             Civil         2
# ...

# %%
df.head()
# Out:
#    student_id          name  age  gender        department  semester  \
# 0        1001  Aarav Sharma   19    Male  Computer Science         2
# 1        1002   Priya Patel   20  Female  Computer Science         2
# 2        1003   Rohit Verma   19    Male       Electronics         2
# 3        1004   Sneha Reddy   20  Female        Mechanical         2
# 4        1005    Arjun Nair   19    Male  Computer Science         2
#
#    math_score  science_score  english_score  programming_score  \
# 0          85             78             72                 91
# 1          76             82             88                 79
# 2          65             74             61                 55
# 3          70             80             75                 48
# 4          92             88             81                 95
#
#    attendance_percentage       city  admission_year
# 0                     92     Mumbai            2023
# 1                     87  Ahmedabad            2023
# ...

# %%
df.tail()
# Out:
#     student_id            name  age  gender        department  semester  \
# 25        1026      Rekha Nair   20  Female       Electronics         2
# 26        1027   Gaurav Shukla   21    Male  Computer Science         2
# 27        1028   Sunita Pillai   19  Female             Civil         2
# 28        1029      Nitin Jain   20    Male        Mechanical         2
# 29        1030  Akanksha Yadav   19  Female  Computer Science         2
#
#     math_score  science_score  english_score  programming_score  \
# 25          72             77             73                 63
# 26          84             79             75                 87
# 27          60             65             68                 39
# 28          75             76             70                 50
# 29          91             93             87                 94
#
#     attendance_percentage                city  admission_year
# 25                     82               Kochi            2023
# ...

# %%
print("Shape of datasset",df.shape)
# Out:
# Shape of datasset (30, 13)

# %%
print("Number of students",df.shape[0])
# Out:
# Number of students 30

# %%
print("Number of columns",df.shape[1])
# Out:
# Number of columns 13

# %%
print("Colum is the dataset:")
print(df.columns.tolist)
# Out:
# Colum is the dataset:
# <bound method IndexOpsMixin.tolist of Index(['student_id', 'name', 'age', 'gender', 'department', 'semester',
#        'math_score', 'science_score', 'english_score', 'programming_score',
#        'attendance_percentage', 'city', 'admission_year'],
#       dtype='object')>

# %%
high_attendance=df[df['attendance_percentage']>90]
print(f"Students with attendance above 90%: {len(high_attendance)}")
print(high_attendance[['name','department','attendance_percentage']])
# Out:
# Students with attendance above 90%: 10
#               name        department  attendance_percentage
# 0     Aarav Sharma  Computer Science                     92
# 3      Sneha Reddy        Mechanical                     95
# 7      Divya Singh  Computer Science                     96
# 9       Ananya Das  Computer Science                     98
# 13   Kavya Nambiar        Mechanical                     91
# 15    Ritu Agarwal       Electronics                     93
# 17  Swati Kulkarni  Computer Science                     94
# 21     Tanvi Mehta  Computer Science                     97
# 24       Amit Bose  Computer Science                     91
# 29  Akanksha Yadav  Computer Science                     95

# %%
df['total_score']=df['math_score']+df['science_score']+df['programming_score']
toppers=df[df['total_score']/4>90]
print(toppers[['name','total_score']])
print("\nNumber of topper",toppers)
# Out:
# Empty DataFrame
# Columns: [name, total_score]
# Index: []
#
# Number of topper Empty DataFrame
# Columns: [student_id, name, age, gender, department, semester, math_score, science_score, english_score, programming_score, attendance_percentage, city, admission_year, total_score]
# Index: []

# %%
# Out:
# Top Student:
# Name:Ananya Das
# Department:Computer Science
# Total Score:371
# Attendance:98%

# %%
dept_avg=df.groupby('department')['total_score'].mean().round(2)
print("Average Total Score by department:")
print(dept_avg)
# Out:
# Average Total Score by department:
# department
# Civil               170.60
# Computer Science    259.31
# Electronics         206.67
# Mechanical          196.83
# Name: total_score, dtype: float64

# %%
# Calculate the average total score for each department
average_total_per_dept = df.groupby('department')['total_score'].mean().reset_index().round(2)
average_total_per_dept.columns = ['Department', 'Average Total Score']
average_total_per_dept = average_total_per_dept.sort_values(by='Average Total Score', ascending=False).reset_index(drop=True)

print(average_total_per_dept)
# Out:
#          Department  Average Total Score
# 0  Computer Science               259.31
# 1       Electronics               206.67
# 2        Mechanical               196.83
# 3             Civil               170.60

# %%
dept_avg=df.groupby('department')['total_score'].mean()
print("Average Total Score per department(Desending order)")
print(dept_avg.sort_values(ascending=False))
# Out:
# Average Total Score per department(Desending order)
# department
# Computer Science    259.307692
# Electronics         206.666667
# Mechanical          196.833333
# Civil               170.600000
# Name: total_score, dtype: float64
